# %% [markdown]
# ## 데이터 준비
# - https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/

# %%
import pandas as pd

# %%
cols = ['Series_Title', 'Released_Year', 'Meta_score', 'IMDB_Rating', 'Overview']

# %%
# 가져올 열 지정하기
mdf = pd.read_csv('imdb_top_1000.csv', usecols=cols)
mdf
# Out:
#                  Series_Title Released_Year  IMDB_Rating  \
# 0    The Shawshank Redemption          1994          9.3
# 1               The Godfather          1972          9.2
# 2             The Dark Knight          2008          9.0
# 3      The Godfather: Part II          1974          9.0
# 4                12 Angry Men          1957          9.0
# ..                        ...           ...          ...
# 995    Breakfast at Tiffany's          1961          7.6
# 996                     Giant          1956          7.6
# 997     From Here to Eternity          1953          7.6
# 998                  Lifeboat          1944          7.6
# 999              The 39 Steps          1935          7.6
#
#                                               Overview  Meta_score
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 열 조회

# %%
# 단일 열 조회를 하면 Series가 return된다.
mdf['Series_Title']
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %%
# 다중 열 조회를 하면 DataFrame
mdf[['Series_Title','IMDB_Rating']]
# Out:
#                  Series_Title  IMDB_Rating
# 0    The Shawshank Redemption          9.3
# 1               The Godfather          9.2
# 2             The Dark Knight          9.0
# 3      The Godfather: Part II          9.0
# 4                12 Angry Men          9.0
# ..                        ...          ...
# 995    Breakfast at Tiffany's          7.6
# 996                     Giant          7.6
# 997     From Here to Eternity          7.6
# 998                  Lifeboat          7.6
# 999              The 39 Steps          7.6
#
# [1000 rows x 2 columns]

# %%
# 없는 열을 조회하면 Error
mdf['AAA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AAA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 # 없는 열을 조회하면 Error
# ----> 2 mdf['AAA']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'AAA'

# %% [markdown]
# 좀 더 안전하게 가져올 땐, 파이썬 Dictionary처럼 .get()를 이용해보자.

# %%
mdf.get(['Series_Title'])
# Out:
#                  Series_Title
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# ..                        ...
# 995    Breakfast at Tiffany's
# 996                     Giant
# 997     From Here to Eternity
# 998                  Lifeboat
# 999              The 39 Steps
#
# [1000 rows x 1 columns]

# %%
mdf.get(['Series_Title','IMDB_Rating'])
# Out:
#                  Series_Title  IMDB_Rating
# 0    The Shawshank Redemption          9.3
# 1               The Godfather          9.2
# 2             The Dark Knight          9.0
# 3      The Godfather: Part II          9.0
# 4                12 Angry Men          9.0
# ..                        ...          ...
# 995    Breakfast at Tiffany's          7.6
# 996                     Giant          7.6
# 997     From Here to Eternity          7.6
# 998                  Lifeboat          7.6
# 999              The 39 Steps          7.6
#
# [1000 rows x 2 columns]

# %%
mdf.get('AAA') #none 오류안남

# %% [markdown]
# 1. 에러 발생을 제어할 건지
# 2. `.get()`함수로 안전하게 조회할 건지 결정
# 3. `[ ]` 로 접근하는 건 address access고 .get()조회하는 건 return value(값 반환)이라서
# 4. 전자는 접근 후 수정이 되고, 후자는 수정이 되지 않는다.

# %% [markdown]
# ## 열 추가 - 1. 일련화 된 값
# - 내가 본 영화를 체크하는 란을 만들자.
# - 리스트의 .append()처럼 위치는 지정할 수 없다. (뒤에 붙음)

# %%
# 마치 dict형에서 값 추가하듯
mdf['watch']=False

# %%
# 확인해 보면
mdf.head()
# Out:
#                Series_Title Released_Year  IMDB_Rating  \
# 0  The Shawshank Redemption          1994          9.3
# 1             The Godfather          1972          9.2
# 2           The Dark Knight          2008          9.0
# 3    The Godfather: Part II          1974          9.0
# 4              12 Angry Men          1957          9.0
#
#                                             Overview  Meta_score  watch
# 0  Two imprisoned men bond over a number of years...        80.0  False
# 1  An organized crime dynasty's aging patriarch t...       100.0  False
# 2  When the menace known as the Joker wreaks havo...        84.0  False
# 3  The early life and career of Vito Corleone in ...        90.0  False
# 4  A jury holdout attempts to prevent a miscarria...        96.0  False

# %% [markdown]
# ## 열 추가 - 2. .insert()를 이용한 일련화된 값
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.insert.html
# - 나만의 평점을 추가해본다고 하자
# - .insert()를 이용하면 위치도 지정할 수 있다.

# %% [markdown]
# **loc : int**
# Insertion index. Must verify 0 <= loc <= len(columns).
#
# **column :str, number, or hashable object**
# Label of the inserted column.
#
# **value : Scalar, Series, or array-like**
#
# **allow_duplicates : bool, optional, default lib.no_default**

# %% [markdown]
# - Scalar : 단일 값

# %%
# Watched 앞에 넣어보자 ->  추가된 후 최종 위치 -> 0 1 2 3 4 [5] 6위치
mdf.insert(loc=5, column='My_score', value=None)

# %%
# 조회
mdf.head()
# Out:
#                Series_Title Released_Year  IMDB_Rating  \
# 0  The Shawshank Redemption          1994          9.3
# 1             The Godfather          1972          9.2
# 2           The Dark Knight          2008          9.0
# 3    The Godfather: Part II          1974          9.0
# 4              12 Angry Men          1957          9.0
#
#                                             Overview  Meta_score My_score  \
# 0  Two imprisoned men bond over a number of years...        80.0     None
# 1  An organized crime dynasty's aging patriarch t...       100.0     None
# 2  When the menace known as the Joker wreaks havo...        84.0     None
# 3  The early life and career of Vito Corleone in ...        90.0     None
# 4  A jury holdout attempts to prevent a miscarria...        96.0     None
#
#    watch
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %% [markdown]
# ## 열 추가 - 3. 다양한 값 추가(Series or array-like)

# %% [markdown]
# - value인자 설명을 보면 Series or array-like
# - Series와 array-like가 개수만 맞다면 추가 가능

# %% [markdown]
# 일단은 `My_Score`, `Watched`를 삭제 drop합시다.

# %%
# 지난 수업 복습겸 작성해보자.
mdf.drop(columns=['My_score', 'watch'], inplace=True)

# %%
mdf.head()
# Out:
#                Series_Title Released_Year  IMDB_Rating  \
# 0  The Shawshank Redemption          1994          9.3
# 1             The Godfather          1972          9.2
# 2           The Dark Knight          2008          9.0
# 3    The Godfather: Part II          1974          9.0
# 4              12 Angry Men          1957          9.0
#
#                                             Overview  Meta_score
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0

# %% [markdown]
# ### 예시1. Watched를 리스트로 추가해보기

# %%
# 예시 watched 생성
watched=[True, False]*500
watched

# %%
# 처음 배운 [] 방식으로 추가하기
mdf['watched']=watched
mdf.head()
# Out:
#                Series_Title Released_Year  IMDB_Rating  \
# 0  The Shawshank Redemption          1994          9.3
# 1             The Godfather          1972          9.2
# 2           The Dark Knight          2008          9.0
# 3    The Godfather: Part II          1974          9.0
# 4              12 Angry Men          1957          9.0
#
#                                             Overview  Meta_score  watched
# 0  Two imprisoned men bond over a number of years...        80.0     True
# 1  An organized crime dynasty's aging patriarch t...       100.0    False
# 2  When the menace known as the Joker wreaks havo...        84.0     True
# 3  The early life and career of Vito Corleone in ...        90.0    False
# 4  A jury holdout attempts to prevent a miscarria...        96.0     True

# %% [markdown]
# ### 예시 2. My_Score를 시리즈로 추가해보기

# %%
import random
my_score = [random.randint(0, 10) for x in range(1000)]
my_score
# Out:
# [8,
#  4,
#  10,
#  1,
#  0,
#  8,
#  9,
#  0,
#  8,
#  3,
#  3,
#  9,
#  5,
#  0,
#  8,
#  3,
#  9,
#  7,
#  2,
#  0,
#  8,
#  8,
#  2,
#  9,
#  6,
#  7,
#  8,
#  0,
#  4,
#  7,
#  7,
#  7,
#  4,
#  0,
#  1,
#  10,
#  0,
#  6,
#  8,
#  7,
#  4,
#  6,
#  8,
#  3,
#  3,
#  9,
#  1,
#  4,
#  9,
#  2,
#  5,
#  4,
#  10,
#  0,
#  7,
#  8,
#  6,
#  5,
#  8,
#  7,
#  0,
#  3,
#  0,
#  6,
#  6,
#  10,
#  3,
#  10,
#  10,
#  0,
#  0,
#  9,
#  5,
#  10,
#  1,
#  10,
#  9,
#  5,
#  1,
#  2,
#  7,
#  4,
#  2,
#  10,
#  7,
#  8,
#  1,
#  9,
#  4,
#  2,
#  8,
#  3,
#  0,
#  8,
#  1,
#  1,
#  6,
#  4,
#  2,
#  6,
#  4,
#  10,
#  4,
#  3,
#  8,
#  5,
#  7,
#  1,
#  0,
#  4,
#  1,
#  5,
#  1,
#  5,
#  4,
#  2,
#  3,
#  5,
#  1,
#  8,
#  1,
#  10,
#  7,
#  1,
#  6,
#  7,
#  1,
#  7,
#  8,
#  5,
#  5,
#  4,
#  8,
#  9,
#  3,
#  2,
#  9,
#  1,
#  10,
#  10,
#  7,
#  10,
#  5,
#  9,
#  6,
#  6,
#  10,
#  8,
#  9,
#  6,
#  6,
#  5,
#  10,
#  6,
#  2,
#  0,
#  9,
#  1,
#  0,
#  8,
#  2,
#  6,
#  0,
#  4,
#  0,
#  5,
#  0,
#  1,
#  5,
#  10,
#  10,
#  5,
#  10,
#  7,
#  5,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  1,
#  1,
#  7,
#  4,
#  4,
#  8,
#  6,
#  3,
#  3,
#  6,
#  9,
#  1,
#  5,
#  2,
#  3,
#  9,
#  4,
#  3,
#  6,
#  4,
#  2,
#  7,
#  9,
#  9,
#  1,
#  0,
#  6,
#  10,
#  7,
#  4,
#  6,
#  8,
#  1,
#  10,
#  5,
#  5,
#  6,
#  2,
#  4,
#  6,
#  3,
#  2,
#  1,
#  0,
#  1,
#  2,
#  3,
#  0,
#  9,
#  2,
#  1,
#  0,
#  4,
#  8,
#  3,
#  0,
#  5,
#  8,
#  8,
#  0,
#  8,
#  5,
#  10,
#  4,
#  1,
#  9,
#  3,
#  4,
#  3,
#  4,
#  6,
#  2,
#  0,
#  9,
#  5,
#  10,
#  8,
#  8,
#  6,
#  6,
#  9,
#  5,
#  4,
#  10,
#  2,
#  0,
#  2,
#  4,
#  3,
#  2,
#  4,
#  10,
#  9,
#  4,
#  5,
#  7,
#  1,
#  3,
#  9,
#  8,
#  9,
#  1,
#  2,
#  0,
#  8,
#  10,
#  1,
#  9,
#  2,
#  1,
#  8,
#  7,
#  0,
#  5,
#  2,
#  2,
#  8,
#  7,
#  3,
#  2,
#  0,
#  5,
#  1,
#  1,
#  0,
#  7,
#  10,
#  10,
#  9,
#  0,
#  4,
#  4,
#  3,
#  4,
#  5,
#  6,
#  8,
#  0,
#  7,
#  0,
#  4,
#  1,
#  5,
#  2,
#  0,
#  5,
#  4,
#  4,
#  10,
#  4,
#  0,
#  3,
#  10,
#  7,
#  4,
#  2,
#  9,
#  5,
#  8,
#  0,
#  7,
#  1,
#  9,
#  4,
#  9,
#  7,
#  7,
#  9,
#  9,
#  7,
#  4,
#  4,
#  10,
#  0,
#  7,
#  6,
#  8,
#  4,
#  8,
#  7,
#  10,
#  10,
#  4,
#  3,
#  3,
#  3,
#  9,
#  1,
#  5,
#  1,
#  1,
#  1,
#  4,
#  5,
#  7,
#  1,
#  5,
#  5,
#  4,
#  9,
#  5,
#  8,
#  5,
#  10,
#  4,
#  2,
#  7,
#  4,
#  4,
#  9,
#  6,
#  10,
#  7,
#  3,
#  2,
#  6,
#  10,
#  0,
#  2,
#  8,
#  2,
#  0,
#  3,
#  8,
#  3,
#  6,
#  7,
#  8,
#  7,
#  5,
#  10,
#  3,
#  9,
#  10,
#  8,
#  3,
#  10,
#  6,
#  5,
#  9,
#  3,
#  3,
#  9,
#  4,
#  2,
#  7,
#  4,
#  2,
#  6,
#  6,
#  10,
#  7,
#  0,
#  1,
#  10,
#  9,
#  3,
#  8,
#  8,
#  5,
#  0,
#  1,
#  7,
#  4,
#  5,
#  10,
#  5,
#  8,
#  10,
#  2,
#  0,
#  1,
#  8,
#  7,
#  10,
#  8,
#  4,
#  7,
#  8,
#  0,
#  7,
#  5,
#  3,
#  7,
#  4,
#  0,
#  0,
#  2,
#  7,
#  4,
#  10,
#  9,
#  7,
#  2,
#  6,
#  4,
#  3,
#  1,
#  3,
#  5,
#  6,
#  4,
#  3,
#  6,
#  10,
#  10,
#  9,
#  9,
#  7,
#  7,
#  1,
#  3,
#  7,
#  8,
#  3,
#  3,
#  5,
#  3,
#  9,
#  7,
#  4,
#  10,
#  4,
#  7,
#  5,
#  7,
#  7,
#  7,
#  8,
#  2,
#  1,
#  9,
#  5,
#  1,
#  3,
#  4,
#  10,
#  5,
#  9,
#  6,
#  8,
#  0,
#  0,
#  8,
#  5,
#  4,
#  10,
#  9,
#  1,
#  10,
#  1,
#  1,
#  4,
#  5,
#  9,
#  7,
#  2,
#  3,
#  9,
#  8,
#  8,
#  3,
#  4,
#  7,
#  5,
#  3,
#  3,
#  10,
#  3,
#  9,
#  5,
#  3,
#  10,
#  9,
#  10,
#  2,
#  5,
#  7,
#  6,
#  2,
#  9,
#  3,
#  10,
#  8,
#  3,
#  10,
#  2,
#  3,
#  6,
#  10,
#  2,
#  3,
#  8,
#  6,
#  5,
#  10,
#  9,
#  1,
#  3,
#  0,
#  10,
#  1,
#  10,
#  8,
#  10,
#  10,
#  3,
#  4,
#  4,
#  5,
#  10,
#  7,
#  6,
#  4,
#  5,
#  4,
#  2,
#  8,
#  10,
#  8,
#  3,
#  1,
#  4,
#  10,
#  4,
#  6,
#  5,
#  2,
#  1,
#  2,
#  7,
#  10,
#  5,
#  3,
#  3,
#  7,
#  1,
#  5,
#  5,
#  6,
#  5,
#  1,
#  10,
#  3,
#  1,
#  0,
#  4,
#  8,
#  6,
#  10,
#  0,
#  1,
#  3,
#  4,
#  4,
#  0,
#  7,
#  9,
#  5,
#  3,
#  6,
#  8,
#  4,
#  4,
#  5,
#  7,
#  6,
#  2,
#  9,
#  3,
#  10,
#  7,
#  5,
#  5,
#  1,
#  7,
#  6,
#  6,
#  1,
#  4,
#  1,
#  1,
#  1,
#  6,
#  2,
#  0,
#  6,
#  7,
#  5,
#  5,
#  6,
#  3,
#  8,
#  7,
#  3,
#  7,
#  8,
#  8,
#  8,
#  8,
#  0,
#  6,
#  3,
#  6,
#  1,
#  8,
#  5,
#  9,
#  9,
#  10,
#  1,
#  1,
#  3,
#  2,
#  9,
#  6,
#  0,
#  5,
#  3,
#  8,
#  0,
#  5,
#  8,
#  10,
#  0,
#  5,
#  6,
#  3,
#  7,
#  7,
#  3,
#  0,
#  3,
#  2,
#  4,
#  2,
#  0,
#  7,
#  5,
#  7,
#  6,
#  0,
#  7,
#  5,
#  1,
#  5,
#  7,
#  1,
#  2,
#  8,
#  10,
#  3,
#  7,
#  4,
#  3,
#  4,
#  7,
#  3,
#  9,
#  1,
#  1,
#  2,
#  9,
#  6,
#  3,
#  7,
#  9,
#  1,
#  4,
#  3,
#  5,
#  3,
#  4,
#  5,
#  6,
#  6,
#  6,
#  8,
#  4,
#  2,
#  8,
#  9,
#  9,
#  4,
#  6,
#  0,
#  4,
#  0,
#  7,
#  7,
#  5,
#  3,
#  6,
#  10,
#  0,
#  10,
#  0,
#  8,
#  5,
#  10,
#  2,
#  3,
#  4,
#  3,
#  3,
#  0,
#  1,
#  4,
#  1,
#  10,
#  10,
#  4,
#  8,
#  4,
#  6,
#  1,
#  5,
#  5,
#  2,
#  4,
#  5,
#  3,
#  6,
#  0,
#  10,
#  2,
#  8,
#  10,
#  10,
#  8,
#  10,
#  7,
#  4,
#  1,
#  3,
#  2,
#  9,
#  2,
#  5,
#  5,
#  7,
#  1,
#  4,
#  7,
#  10,
#  8,
#  2,
#  2,
#  5,
#  9,
#  9,
#  3,
#  1,
#  3,
#  9,
#  6,
#  9,
#  6,
#  9,
#  5,
#  7,
#  8,
#  6,
#  3,
#  8,
#  8,
#  1,
#  2,
#  10,
#  7,
#  3,
#  1,
#  5,
#  9,
#  5,
#  8,
#  9,
#  7,
#  6,
#  1,
#  10,
#  9,
#  5,
#  0,
#  7,
#  4,
#  9,
#  1,
#  5,
#  4,
#  8,
#  2,
#  6,
#  9,
#  9,
#  9,
#  7,
#  0,
#  5,
#  4,
#  7,
#  9,
#  0,
#  8,
#  4,
#  5,
#  10,
#  5,
#  7,
#  2,
#  7,
#  9,
#  6,
#  8,
#  8,
#  0,
#  8,
#  6,
#  2,
#  1,
#  10,
#  8,
#  7,
#  1,
#  4,
#  8,
#  7,
#  3,
#  2,
#  4,
#  2,
#  3,
#  2,
#  8,
#  1,
#  5,
#  6,
#  4,
#  0,
#  3,
#  8,
#  7,
#  2,
#  6,
#  9,
#  6,
#  5,
#  5,
#  1,
#  10,
#  3,
#  8,
#  8,
#  10,
#  0,
#  0,
#  5,
#  1,
#  0,
#  3,
#  7,
#  7,
#  5,
#  1,
#  3,
#  10,
#  2,
#  9,
#  1,
#  8,
#  9,
#  2,
#  9,
#  0,
#  4,
#  9,
#  1,
#  2,
#  0,
#  0,
#  5,
#  6,
#  1,
#  2,
#  5,
#  1,
#  3,
#  5,
#  4,
#  10,
#  9,
#  1,
#  1,
#  2,
#  7,
#  8,
#  2,
#  1,
#  6,
#  1,
#  4,
#  7,
#  2,
#  8,
#  2,
#  6,
#  3,
#  8,
#  3,
#  9,
#  2,
#  4,
#  7,
#  7,
#  10,
#  0,
#  5,
#  7,
#  6]

# %%
# 시리즈 생성
my_score_series=pd.Series(my_score)
my_score_series.head()
# Out:
# 0     8
# 1     4
# 2    10
# 3     1
# 4     0
# dtype: int64

# %%
# IMDB_Rating 앞에 추가해보자. 개수가 동일해야함
mdf.insert(loc=2, column='My_score', value=my_score_series)

# %%
# 확인
mdf.head()
# Out:
#                Series_Title Released_Year  My_score  IMDB_Rating  \
# 0  The Shawshank Redemption          1994         8          9.3
# 1             The Godfather          1972         4          9.2
# 2           The Dark Knight          2008        10          9.0
# 3    The Godfather: Part II          1974         1          9.0
# 4              12 Angry Men          1957         0          9.0
#
#                                             Overview  Meta_score  watched
# 0  Two imprisoned men bond over a number of years...        80.0     True
# 1  An organized crime dynasty's aging patriarch t...       100.0    False
# 2  When the menace known as the Joker wreaks havo...        84.0     True
# 3  The early life and career of Vito Corleone in ...        90.0    False
# 4  A jury holdout attempts to prevent a miscarria...        96.0     True

# %% [markdown]
# ## 만일 데이터의 개수가 안 맞는다면?

# %% [markdown]
# ### 테스트 1 : [] + `array-like` 로 열 추가 방식

# %%
watched
# Out:
# [True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False]

# %%
del watched[0]

# %%
len(watched)
# Out:
# 999

# %%
# 테스트 1000개 <-999개  : 에러발생
mdf['watched_new']=watched
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 # 테스트 1000개 <-999개  : 에러발생
# ----> 2 mdf['watched_new']=watched
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5039, in DataFrame._sanitize_column(self, value)
#    5036     return _reindex_for_setitem(value, self.index)
#    5038 if is_list_like(value):
# -> 5039     com.require_length_match(value, self.index)
#    5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (999) does not match length of index (1000)

# %% [markdown]
# ValueError: Length of values (999) does not match length of index (1000)

# %% [markdown]
# ### 테스트 2 : insert+`Series`로 열 추가 방식

# %%
del my_score_series[1]
my_score_series.size
# Out:
# 998

# %%
# 테스트 1000개 <-999개  : 에러 발생?
mdf.insert(loc=2, column='my_new_score', value=my_score_series)

# %%
mdf.head()
# Out:
#                Series_Title Released_Year  my_new_score  My_score  \
# 0  The Shawshank Redemption          1994           NaN         8
# 1             The Godfather          1972           NaN         4
# 2           The Dark Knight          2008          10.0        10
# 3    The Godfather: Part II          1974           1.0         1
# 4              12 Angry Men          1957           0.0         0
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#    watched
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True

# %% [markdown]
# 1. 일치된 인덱스에 맞춰 값이 추가된다.
# 2. 일치되지 않은 행은 NaN으로 대체된다.

# %% [markdown]
# 데이터 전처리를 열심히 하다보면 이렇게 NaN데이터가 쉽게 생겨나기도 한다.

# %% [markdown]
# ### 테스트 3. [] + `Series` 추가하면?

# %%
mdf['new_watch']=my_score_series

# %%
mdf.head()
# Out:
#                Series_Title Released_Year  my_new_score  My_score  \
# 0  The Shawshank Redemption          1994           NaN         8
# 1             The Godfather          1972           NaN         4
# 2           The Dark Knight          2008          10.0        10
# 3    The Godfather: Part II          1974           1.0         1
# 4              12 Angry Men          1957           0.0         0
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#    watched  new_watch
# 0     True        NaN
# 1    False        NaN
# 2     True       10.0
# 3    False        1.0
# 4     True        0.0
