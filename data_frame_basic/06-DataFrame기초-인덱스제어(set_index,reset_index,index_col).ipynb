# %% [markdown]
# ## 데이터 준비
# - https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/

# %%
import pandas as pd

# %%
cols = ['Released_Year', 'Genre', 'Series_Title', 'Director', 'Meta_score', 'IMDB_Rating', 'No_of_Votes', 'Certificate', 'Gross']

# %%
# 가져올 열 지정하기
mdf=pd.read_csv('imdb_top_1000.csv')
mdf=mdf[cols]
mdf
# Out:
#     Released_Year                     Genre              Series_Title  \
# 0            1994                     Drama  The Shawshank Redemption
# 1            1972              Crime, Drama             The Godfather
# 2            2008      Action, Crime, Drama           The Dark Knight
# 3            1974              Crime, Drama    The Godfather: Part II
# 4            1957              Crime, Drama              12 Angry Men
# ..            ...                       ...                       ...
# 995          1961    Comedy, Drama, Romance    Breakfast at Tiffany's
# 996          1956            Drama, Western                     Giant
# 997          1953       Drama, Romance, War     From Here to Eternity
# 998          1944                Drama, War                  Lifeboat
# 999          1935  Crime, Mystery, Thriller              The 39 Steps
#
#                  Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0          Frank Darabont        80.0          9.3      2343110           A
# 1    Francis Ford Coppola       100.0          9.2      1620367           A
# 2       Christopher Nolan        84.0          9.0      2303232          UA
# 3    Francis Ford Coppola        90.0          9.0      1129952           A
# 4            Sidney Lumet        96.0          9.0       689845           U
# ..                    ...         ...          ...          ...         ...
# 995         Blake Edwards        76.0          7.6       166544           A
# 996        George Stevens        84.0          7.6        34075           G
# 997        Fred Zinnemann        85.0          7.6        43374      Passed
# 998      Alfred Hitchcock        78.0          7.6        26471         NaN
# 999      Alfred Hitchcock        93.0          7.6        51853         NaN
#
#            Gross
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# ..           ...
# 995          NaN
# 996          NaN
# 997   30,500,000
# 998          NaN
# 999          NaN
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## .set_index()
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
# - 특정 열을 인덱스로 설정하는 기능을 제공
# - 현재 숫자형 인덱스를 다른 열로 지정해보자.

# %%
# 영화 제목을 인덱스로 설정하면
mdf.set_index('Series_Title')
# Out:
#                          Released_Year                     Genre  \
# Series_Title
# The Shawshank Redemption          1994                     Drama
# The Godfather                     1972              Crime, Drama
# The Dark Knight                   2008      Action, Crime, Drama
# The Godfather: Part II            1974              Crime, Drama
# 12 Angry Men                      1957              Crime, Drama
# ...                                ...                       ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance
# Giant                             1956            Drama, Western
# From Here to Eternity             1953       Drama, Romance, War
# Lifeboat                          1944                Drama, War
# The 39 Steps                      1935  Crime, Mystery, Thriller
#
#                                       Director  Meta_score  IMDB_Rating  \
# Series_Title
# The Shawshank Redemption        Frank Darabont        80.0          9.3
# The Godfather             Francis Ford Coppola       100.0          9.2
# The Dark Knight              Christopher Nolan        84.0          9.0
# The Godfather: Part II    Francis Ford Coppola        90.0          9.0
# 12 Angry Men                      Sidney Lumet        96.0          9.0
# ...                                        ...         ...          ...
# Breakfast at Tiffany's           Blake Edwards        76.0          7.6
# Giant                           George Stevens        84.0          7.6
# From Here to Eternity           Fred Zinnemann        85.0          7.6
# Lifeboat                      Alfred Hitchcock        78.0          7.6
# The 39 Steps                  Alfred Hitchcock        93.0          7.6
#
#                           No_of_Votes Certificate        Gross
# Series_Title
# The Shawshank Redemption      2343110           A   28,341,469
# The Godfather                 1620367           A  134,966,411
# The Dark Knight               2303232          UA  534,858,444
# The Godfather: Part II        1129952           A   57,300,000
# 12 Angry Men                   689845           U    4,360,000
# ...                               ...         ...          ...
# Breakfast at Tiffany's         166544           A          NaN
# Giant                           34075           G          NaN
# From Here to Eternity           43374      Passed   30,500,000
# Lifeboat                        26471         NaN          NaN
# The 39 Steps                    51853         NaN          NaN
#
# [1000 rows x 8 columns]

# %% [markdown]
# - 비파괴적 처리기 때문에 저장은 안되었다.
# - 인덱스 열로 지정되면서 사용된 열이 삭제되었다. (마치 move처럼)
# - .set_index도 inplace= 인자를 제공한다.

# %% [markdown]
# ## .set_index()의 drop=
# - .set_index()로 index열을 변경할 때, 인덱스로 지정된 열을 기존 열에서 삭제할 지 여부를 정한다.
# - default가 True라서 삭제된다.

# %%
# 영화 제목을 인덱스로 설정, drop=False라서 Series_Title이 여전히 열에 있다.
mdf.set_index('Series_Title' , drop=False)
# Out:
#                          Released_Year                     Genre  \
# Series_Title
# The Shawshank Redemption          1994                     Drama
# The Godfather                     1972              Crime, Drama
# The Dark Knight                   2008      Action, Crime, Drama
# The Godfather: Part II            1974              Crime, Drama
# 12 Angry Men                      1957              Crime, Drama
# ...                                ...                       ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance
# Giant                             1956            Drama, Western
# From Here to Eternity             1953       Drama, Romance, War
# Lifeboat                          1944                Drama, War
# The 39 Steps                      1935  Crime, Mystery, Thriller
#
#                                       Series_Title              Director  \
# Series_Title
# The Shawshank Redemption  The Shawshank Redemption        Frank Darabont
# The Godfather                        The Godfather  Francis Ford Coppola
# The Dark Knight                    The Dark Knight     Christopher Nolan
# The Godfather: Part II      The Godfather: Part II  Francis Ford Coppola
# 12 Angry Men                          12 Angry Men          Sidney Lumet
# ...                                            ...                   ...
# Breakfast at Tiffany's      Breakfast at Tiffany's         Blake Edwards
# Giant                                        Giant        George Stevens
# From Here to Eternity        From Here to Eternity        Fred Zinnemann
# Lifeboat                                  Lifeboat      Alfred Hitchcock
# The 39 Steps                          The 39 Steps      Alfred Hitchcock
#
#                           Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# Series_Title
# The Shawshank Redemption        80.0          9.3      2343110           A
# The Godfather                  100.0          9.2      1620367           A
# The Dark Knight                 84.0          9.0      2303232          UA
# The Godfather: Part II          90.0          9.0      1129952           A
# 12 Angry Men                    96.0          9.0       689845           U
# ...                              ...          ...          ...         ...
# Breakfast at Tiffany's          76.0          7.6       166544           A
# Giant                           84.0          7.6        34075           G
# From Here to Eternity           85.0          7.6        43374      Passed
# Lifeboat                        78.0          7.6        26471         NaN
# The 39 Steps                    93.0          7.6        51853         NaN
#
#                                 Gross
# Series_Title
# The Shawshank Redemption   28,341,469
# The Godfather             134,966,411
# The Dark Knight           534,858,444
# The Godfather: Part II     57,300,000
# 12 Angry Men                4,360,000
# ...                               ...
# Breakfast at Tiffany's            NaN
# Giant                             NaN
# From Here to Eternity      30,500,000
# Lifeboat                          NaN
# The 39 Steps                      NaN
#
# [1000 rows x 9 columns]

# %%
# 영화 제목을 인덱스로 설정, drop=True라서 Series_Title가 열에서 없어졌다.
mdf.set_index('Series_Title' , drop=True)
mdf
# Out:
#     Released_Year                     Genre              Series_Title  \
# 0            1994                     Drama  The Shawshank Redemption
# 1            1972              Crime, Drama             The Godfather
# 2            2008      Action, Crime, Drama           The Dark Knight
# 3            1974              Crime, Drama    The Godfather: Part II
# 4            1957              Crime, Drama              12 Angry Men
# ..            ...                       ...                       ...
# 995          1961    Comedy, Drama, Romance    Breakfast at Tiffany's
# 996          1956            Drama, Western                     Giant
# 997          1953       Drama, Romance, War     From Here to Eternity
# 998          1944                Drama, War                  Lifeboat
# 999          1935  Crime, Mystery, Thriller              The 39 Steps
#
#                  Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0          Frank Darabont        80.0          9.3      2343110           A
# 1    Francis Ford Coppola       100.0          9.2      1620367           A
# 2       Christopher Nolan        84.0          9.0      2303232          UA
# 3    Francis Ford Coppola        90.0          9.0      1129952           A
# 4            Sidney Lumet        96.0          9.0       689845           U
# ..                    ...         ...          ...          ...         ...
# 995         Blake Edwards        76.0          7.6       166544           A
# 996        George Stevens        84.0          7.6        34075           G
# 997        Fred Zinnemann        85.0          7.6        43374      Passed
# 998      Alfred Hitchcock        78.0          7.6        26471         NaN
# 999      Alfred Hitchcock        93.0          7.6        51853         NaN
#
#            Gross
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# ..           ...
# 995          NaN
# 996          NaN
# 997   30,500,000
# 998          NaN
# 999          NaN
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## df.index.name =
# - Series_Title이란 이름이 어색한 것 같아서 Title로 변경해보자.

# %%
# 열 변경 후 저장 -> 열 이름 변경
#mdf=mdf.set_index('Series_Title')
mdf.index.name='Title'
mdf
# Out:
#                          Released_Year                     Genre  \
# Title
# The Shawshank Redemption          1994                     Drama
# The Godfather                     1972              Crime, Drama
# The Dark Knight                   2008      Action, Crime, Drama
# The Godfather: Part II            1974              Crime, Drama
# 12 Angry Men                      1957              Crime, Drama
# ...                                ...                       ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance
# Giant                             1956            Drama, Western
# From Here to Eternity             1953       Drama, Romance, War
# Lifeboat                          1944                Drama, War
# The 39 Steps                      1935  Crime, Mystery, Thriller
#
#                                       Director  Meta_score  IMDB_Rating  \
# Title
# The Shawshank Redemption        Frank Darabont        80.0          9.3
# The Godfather             Francis Ford Coppola       100.0          9.2
# The Dark Knight              Christopher Nolan        84.0          9.0
# The Godfather: Part II    Francis Ford Coppola        90.0          9.0
# 12 Angry Men                      Sidney Lumet        96.0          9.0
# ...                                        ...         ...          ...
# Breakfast at Tiffany's           Blake Edwards        76.0          7.6
# Giant                           George Stevens        84.0          7.6
# From Here to Eternity           Fred Zinnemann        85.0          7.6
# Lifeboat                      Alfred Hitchcock        78.0          7.6
# The 39 Steps                  Alfred Hitchcock        93.0          7.6
#
#                           No_of_Votes Certificate        Gross
# Title
# The Shawshank Redemption      2343110           A   28,341,469
# The Godfather                 1620367           A  134,966,411
# The Dark Knight               2303232          UA  534,858,444
# The Godfather: Part II        1129952           A   57,300,000
# 12 Angry Men                   689845           U    4,360,000
# ...                               ...         ...          ...
# Breakfast at Tiffany's         166544           A          NaN
# Giant                           34075           G          NaN
# From Here to Eternity           43374      Passed   30,500,000
# Lifeboat                        26471         NaN          NaN
# The 39 Steps                    51853         NaN          NaN
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## .reset_index()
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html
# - 인덱스를 초기화합니다.
# - 나중에 배울 MultiIndex 작업도 초기화 합니다.

# %%
# 비파괴적 처리
mdf.reset_index()
# Out:
#                         Title Released_Year                     Genre  \
# 0    The Shawshank Redemption          1994                     Drama
# 1               The Godfather          1972              Crime, Drama
# 2             The Dark Knight          2008      Action, Crime, Drama
# 3      The Godfather: Part II          1974              Crime, Drama
# 4                12 Angry Men          1957              Crime, Drama
# ..                        ...           ...                       ...
# 995    Breakfast at Tiffany's          1961    Comedy, Drama, Romance
# 996                     Giant          1956            Drama, Western
# 997     From Here to Eternity          1953       Drama, Romance, War
# 998                  Lifeboat          1944                Drama, War
# 999              The 39 Steps          1935  Crime, Mystery, Thriller
#
#                  Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0          Frank Darabont        80.0          9.3      2343110           A
# 1    Francis Ford Coppola       100.0          9.2      1620367           A
# 2       Christopher Nolan        84.0          9.0      2303232          UA
# 3    Francis Ford Coppola        90.0          9.0      1129952           A
# 4            Sidney Lumet        96.0          9.0       689845           U
# ..                    ...         ...          ...          ...         ...
# 995         Blake Edwards        76.0          7.6       166544           A
# 996        George Stevens        84.0          7.6        34075           G
# 997        Fred Zinnemann        85.0          7.6        43374      Passed
# 998      Alfred Hitchcock        78.0          7.6        26471         NaN
# 999      Alfred Hitchcock        93.0          7.6        51853         NaN
#
#            Gross
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# ..           ...
# 995          NaN
# 996          NaN
# 997   30,500,000
# 998          NaN
# 999          NaN
#
# [1000 rows x 9 columns]

# %% [markdown]
# 직접 속성에 접근해서 변경한 Series_Title -> Title은 유지되고 있다.

# %% [markdown]
# ## .reset_index()의 drop=
# - 기존 인덱스를 데이터 열로 삽입되지않고 삭제됩니다.
# - 인덱스는 기본 정수형 인덱스로 재설정됩니다.

# %%
mdf.reset_index(drop=True)
# Out:
#     Released_Year                     Genre              Director  Meta_score  \
# 0            1994                     Drama        Frank Darabont        80.0
# 1            1972              Crime, Drama  Francis Ford Coppola       100.0
# 2            2008      Action, Crime, Drama     Christopher Nolan        84.0
# 3            1974              Crime, Drama  Francis Ford Coppola        90.0
# 4            1957              Crime, Drama          Sidney Lumet        96.0
# ..            ...                       ...                   ...         ...
# 995          1961    Comedy, Drama, Romance         Blake Edwards        76.0
# 996          1956            Drama, Western        George Stevens        84.0
# 997          1953       Drama, Romance, War        Fred Zinnemann        85.0
# 998          1944                Drama, War      Alfred Hitchcock        78.0
# 999          1935  Crime, Mystery, Thriller      Alfred Hitchcock        93.0
#
#      IMDB_Rating  No_of_Votes Certificate        Gross
# 0            9.3      2343110           A   28,341,469
# 1            9.2      1620367           A  134,966,411
# 2            9.0      2303232          UA  534,858,444
# 3            9.0      1129952           A   57,300,000
# 4            9.0       689845           U    4,360,000
# ..           ...          ...         ...          ...
# 995          7.6       166544           A          NaN
# 996          7.6        34075           G          NaN
# 997          7.6        43374      Passed   30,500,000
# 998          7.6        26471         NaN          NaN
# 999          7.6        51853         NaN          NaN
#
# [1000 rows x 8 columns]

# %% [markdown]
# 영화 제목(Title) 열이 사라졌다.

# %% [markdown]
# ## index_col = : 읽어올 때 index열 설정하기

# %%
import pandas as pd

# %%
cols = ['Released_Year', 'Genre', 'Series_Title', 'Director', 'Meta_score', 'IMDB_Rating', 'No_of_Votes', 'Certificate', 'Gross']

# %%
# 가져올 열과 인덱스 열을 지정하기
mdf=pd.read_csv('imdb_top_1000.csv', usecols=cols, index_col='Series_Title')
mdf
# Out:
#                          Released_Year Certificate                     Genre  \
# Series_Title
# The Shawshank Redemption          1994           A                     Drama
# The Godfather                     1972           A              Crime, Drama
# The Dark Knight                   2008          UA      Action, Crime, Drama
# The Godfather: Part II            1974           A              Crime, Drama
# 12 Angry Men                      1957           U              Crime, Drama
# ...                                ...         ...                       ...
# Breakfast at Tiffany's            1961           A    Comedy, Drama, Romance
# Giant                             1956           G            Drama, Western
# From Here to Eternity             1953      Passed       Drama, Romance, War
# Lifeboat                          1944         NaN                Drama, War
# The 39 Steps                      1935         NaN  Crime, Mystery, Thriller
#
#                           IMDB_Rating  Meta_score              Director  \
# Series_Title
# The Shawshank Redemption          9.3        80.0        Frank Darabont
# The Godfather                     9.2       100.0  Francis Ford Coppola
# The Dark Knight                   9.0        84.0     Christopher Nolan
# The Godfather: Part II            9.0        90.0  Francis Ford Coppola
# 12 Angry Men                      9.0        96.0          Sidney Lumet
# ...                               ...         ...                   ...
# Breakfast at Tiffany's            7.6        76.0         Blake Edwards
# Giant                             7.6        84.0        George Stevens
# From Here to Eternity             7.6        85.0        Fred Zinnemann
# Lifeboat                          7.6        78.0      Alfred Hitchcock
# The 39 Steps                      7.6        93.0      Alfred Hitchcock
#
#                           No_of_Votes        Gross
# Series_Title
# The Shawshank Redemption      2343110   28,341,469
# The Godfather                 1620367  134,966,411
# The Dark Knight               2303232  534,858,444
# The Godfather: Part II        1129952   57,300,000
# 12 Angry Men                   689845    4,360,000
# ...                               ...          ...
# Breakfast at Tiffany's         166544          NaN
# Giant                           34075          NaN
# From Here to Eternity           43374   30,500,000
# Lifeboat                        26471          NaN
# The 39 Steps                    51853          NaN
#
# [1000 rows x 8 columns]
