# %% [markdown]
# ## 데이터셋
# - 고객 성격 분석 : https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis

# %%
import pandas as pd

# %%
cus = pd.read_csv('marketing_campaign.csv', sep='\t', index_col='ID')
cus
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %% [markdown]
# ## 복습 - 다자녀(2인 이상)을 확인하려면?

# %%
# 마스크로
multiple_child_mask=cus['Kidhome']>=2
cus[multiple_child_mask].head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 7244        1951  Graduation         Single      NaN        2         1
# 8996        1957         PhD        Married      NaN        2         1
# 8442        1985      Master        Married  19510.0        2         0
# 9579        1959         PhD        Married  33762.0        2         1
# 5885        1973    2n Cycle        Married  35688.0        2         1
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 7244  01-01-2014       96        48          5  ...                  6
# 8996  19-11-2012        4       230         42  ...                  9
# 8442  04-09-2013       63         9          0  ...                  7
# 9579  07-07-2013       61        53          1  ...                  8
# 5885  22-08-2012       94        73          3  ...                  8
#
# ...

# %% [markdown]
# ## .where() 를 사용하면
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.where.html
#
# 조건에 맞는 데이터가 아니면 NA를 반환한다.

# %%
cus.where(cus['Kidhome']>=2)
# Out:
#        Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524          NaN       NaN            NaN      NaN      NaN       NaN
# 2174          NaN       NaN            NaN      NaN      NaN       NaN
# 4141          NaN       NaN            NaN      NaN      NaN       NaN
# 6182          NaN       NaN            NaN      NaN      NaN       NaN
# 5324          NaN       NaN            NaN      NaN      NaN       NaN
# ...           ...       ...            ...      ...      ...       ...
# 10870         NaN       NaN            NaN      NaN      NaN       NaN
# 4001       1946.0       PhD       Together  64014.0      2.0       1.0
# 7270          NaN       NaN            NaN      NaN      NaN       NaN
# 8235          NaN       NaN            NaN      NaN      NaN       NaN
# 9405          NaN       NaN            NaN      NaN      NaN       NaN
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %%
# .where()이후 .dropna()
cus.where(cus['Kidhome']>=2).dropna()
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 8442       1985.0      Master        Married  19510.0      2.0       0.0
# 9579       1959.0         PhD        Married  33762.0      2.0       1.0
# 5885       1973.0    2n Cycle        Married  35688.0      2.0       1.0
# 2795       1958.0      Master         Single  30523.0      2.0       1.0
# 4370       1966.0  Graduation       Together  43482.0      2.0       1.0
# 1349       1970.0  Graduation        Married  50447.0      2.0       0.0
# 10492      1959.0  Graduation       Together  38285.0      2.0       1.0
# 7264       1978.0    2n Cycle         Single  52195.0      2.0       1.0
# 3153       1957.0         PhD         Single  40737.0      2.0       1.0
# 4927       1971.0  Graduation       Together  16626.0      2.0       0.0
# 2826       1967.0  Graduation        Married  22574.0      2.0       1.0
# 10350      1950.0         PhD        Married  54432.0      2.0       1.0
# ...

# %% [markdown]
# ## 조건에 맞지않는 데이터는 은닉하기

# %%
# 방법 1. other로 대체하기
cus.where(cus['Kidhome']>=2, other='--')
# Out:
#       Year_Birth Education Marital_Status   Income Kidhome Teenhome  \
# ID
# 5524          --        --             --       --      --       --
# 2174          --        --             --       --      --       --
# 4141          --        --             --       --      --       --
# 6182          --        --             --       --      --       --
# 5324          --        --             --       --      --       --
# ...          ...       ...            ...      ...     ...      ...
# 10870         --        --             --       --      --       --
# 4001        1946       PhD       Together  64014.0       2        1
# 7270          --        --             --       --      --       --
# 8235          --        --             --       --      --       --
# 9405          --        --             --       --      --       --
#
#       Dt_Customer Recency MntWines MntFruits  ... NumWebVisitsMonth  \
# ID                                            ...
# ...

# %%
# 방법 2. default인 NA가 되도록 놓거나 other에 None으로 대체하기
cus.where(cus['Kidhome']>=2, other=None)
# Out:
#        Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524          NaN      None           None      NaN      NaN       NaN
# 2174          NaN      None           None      NaN      NaN       NaN
# 4141          NaN      None           None      NaN      NaN       NaN
# 6182          NaN      None           None      NaN      NaN       NaN
# 5324          NaN      None           None      NaN      NaN       NaN
# ...           ...       ...            ...      ...      ...       ...
# 10870         NaN      None           None      NaN      NaN       NaN
# 4001       1946.0       PhD       Together  64014.0      2.0       1.0
# 7270          NaN      None           None      NaN      NaN       NaN
# 8235          NaN      None           None      NaN      NaN       NaN
# 9405          NaN      None           None      NaN      NaN       NaN
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...
