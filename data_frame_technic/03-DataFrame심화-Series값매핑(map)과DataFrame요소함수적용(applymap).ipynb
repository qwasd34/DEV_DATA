# %% [markdown]
# ## Series.map(arg)
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html#pandas.Series.map

# %%
people_set = {
    'Name' : ['Spencer', 'Mark', 'Tom', 'Peter'],
    'Major': ['Computer', 'Science', 'English', 'Computer'],
    'YearOfJoining' : [2020, 2019, 2018, 2017],
    'DriverLicense' : [True, False, False, True],
    'TeacherCertification' : [True, False, False, False],
}

# %%
import pandas as pd

# %%
pp = pd.DataFrame(people_set)
pp
# Out:
#       Name     Major  YearOfJoining  DriverLicense  TeacherCertification
# 0  Spencer  Computer           2020           True                  True
# 1     Mark   Science           2019          False                 False
# 2      Tom   English           2018          False                 False
# 3    Peter  Computer           2017           True                 False

# %%
# map() 으로 매핑 확인해서 값 변환
pp['DriverLicense']=pp['DriverLicense'].map({True:'Yes', False:'No'})
pp
# Out:
#       Name     Major  YearOfJoining DriverLicense  TeacherCertification
# 0  Spencer  Computer           2020           Yes                  True
# 1     Mark   Science           2019            No                 False
# 2      Tom   English           2018            No                 False
# 3    Peter  Computer           2017           Yes                 False

# %%
# 매핑이 안된 값은 그대로? NA? 일까
pp['TeacherCertification'].map({True: 'Computer'})
# Out:
# 0    Computer
# 1         NaN
# 2         NaN
# 3         NaN
# Name: TeacherCertification, dtype: object

# %%
pp['TeacherCertification'].map({True:'Computer' , False:'Nocertification'}).value_counts()
# Out:
# TeacherCertification
# Nocertification    3
# Computer           1
# Name: count, dtype: int64

# %% [markdown]
# ## Dataframe.applymap(func)
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.applymap.html#pandas.DataFrame.applymap
# - 모든 요소에 apply()를 할 수 있다.

# %%
pp.applymap(type)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\1269525237.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pp.applymap(type)
#             Name          Major  YearOfJoining  DriverLicense  \
# 0  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 1  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 2  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 3  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
#
#   TeacherCertification
# 0       <class 'bool'>
# 1       <class 'bool'>
# 2       <class 'bool'>
# 3       <class 'bool'>

# %%
pp.applymap(str).applymap(type)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\4059411522.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pp.applymap(str).applymap(type)
#             Name          Major  YearOfJoining  DriverLicense  \
# 0  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
#
#   TeacherCertification
# 0        <class 'str'>
# 1        <class 'str'>
# 2        <class 'str'>
# 3        <class 'str'>

# %%
# str같은 경우 Series는 applymap할 필요 없이 가능하나
pp['Name'].str.len()
# Out:
# 0    7
# 1    4
# 2    3
# 3    5
# Name: Name, dtype: int64

# %%
# Dataframe은 .str이 안된다.
pp.str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2932243893.py in ?()
#       1 # Dataframe은 .str이 안된다.
# ----> 2 pp.str
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %% [markdown]
# 모든 요소를 str로 변환하고 대문자로 변환하면

# %%
# 대문자 만드는 함수
def uppercase(data):
    return data.upper()

# %%
pp.applymap(str).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  4 non-null      object
#  1   Major                 4 non-null      object
#  2   YearOfJoining         4 non-null      object
#  3   DriverLicense         4 non-null      object
#  4   TeacherCertification  4 non-null      object
# dtypes: object(5)
# memory usage: 292.0+ bytes
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\1000634324.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pp.applymap(str).info()

# %%
pp.applymap(str).applymap(uppercase)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\2439973040.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pp.applymap(str).applymap(uppercase)
#       Name     Major YearOfJoining DriverLicense TeacherCertification
# 0  SPENCER  COMPUTER          2020           YES                 TRUE
# 1     MARK   SCIENCE          2019            NO                FALSE
# 2      TOM   ENGLISH          2018            NO                FALSE
# 3    PETER  COMPUTER          2017           YES                FALSE

# %% [markdown]
# 사실 모든 요소 형변환 하는 방법은 따로 있긴하다.
# 위에는 사용자가 함수를 만들어서 모든 요소에 적용할 수 있다는 점을 실습해본 것.

# %%
pp.astype(str).applymap(uppercase)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\217496443.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pp.astype(str).applymap(uppercase)
#       Name     Major YearOfJoining DriverLicense TeacherCertification
# 0  SPENCER  COMPUTER          2020           YES                 TRUE
# 1     MARK   SCIENCE          2019            NO                FALSE
# 2      TOM   ENGLISH          2018            NO                FALSE
# 3    PETER  COMPUTER          2017           YES                FALSE

# %%
# Lambda도 살펴보자
df = pd.DataFrame({'A': [1, 2, 3],
                   'B': [4, 5, 6],
                   'C': [7, 8, 9]})

# %%
# applymap()을 사용하여 제곱 연산 적용
df_squared = df.applymap(lambda x: x**2)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\3380807843.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_squared = df.applymap(lambda x: x**2)

# %%
df_squared
# Out:
#    A   B   C
# 0  1  16  49
# 1  4  25  64
# 2  9  36  81

# %%
df **2
# Out:
#    A   B   C
# 0  1  16  49
# 1  4  25  64
# 2  9  36  81

# %% [markdown]
# ## 데이터셋
# - 고객 성격 분석 : https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis

# %%
import pandas as pd

# %%
cus = pd.read_csv('marketing_campaign.csv', sep='\t', index_col='ID')
cus
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                               ...
# 5524   04-09-2012       58       635         88  ...                  7
# 2174   08-03-2014       38        11          1  ...                  5
# 4141   21-08-2013       26       426         49  ...                  4
# 6182   10-02-2014       26        11          4  ...                  6
# 5324   19-01-2014       94       173         43  ...                  5
# ...           ...      ...       ...        ...  ...                ...
# 10870  13-06-2013       46       709         43  ...                  5
# 4001   10-06-2014       56       406          0  ...                  7
# 7270   25-01-2014       91       908         48  ...                  6
# 8235   24-01-2014        8       428         30  ...                  3
# 9405   15-10-2012       40        84          3  ...                  7
#
#        AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ID
# 5524              0             0             0             0             0
# 2174              0             0             0             0             0
# 4141              0             0             0             0             0
# 6182              0             0             0             0             0
# 5324              0             0             0             0             0
# ...             ...           ...           ...           ...           ...
# 10870             0             0             0             0             0
# 4001              0             0             0             1             0
# 7270              0             1             0             0             0
# 8235              0             0             0             0             0
# 9405              0             0             0             0             0
#
#        Complain  Z_CostContact  Z_Revenue  Response
# ID
# 5524          0              3         11         1
# 2174          0              3         11         0
# 4141          0              3         11         0
# 6182          0              3         11         0
# 5324          0              3         11         0
# ...         ...            ...        ...       ...
# 10870         0              3         11         0
# 4001          0              3         11         0
# 7270          0              3         11         0
# 8235          0              3         11         0
# 9405          0              3         11         1
#
# [2240 rows x 28 columns]

# %%
# 다자녀 표시
cus['Kidhome']=cus['Kidhome'].map({0:'자녀없음', 1: '외동', 2: '다자녀'})

# %%
cus.head()
# Out:
#       Year_Birth   Education Marital_Status   Income Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single  58138.0    자녀없음         0
# 2174        1954  Graduation         Single  46344.0      외동         1
# 4141        1965  Graduation       Together  71613.0    자녀없음         0
# 6182        1984  Graduation       Together  26646.0      외동         0
# 5324        1981         PhD        Married  58293.0      외동         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  04-09-2012       58       635         88  ...                  7
# 2174  08-03-2014       38        11          1  ...                  5
# 4141  21-08-2013       26       426         49  ...                  4
# 6182  10-02-2014       26        11          4  ...                  6
# 5324  19-01-2014       94       173         43  ...                  5
#
#       AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ID
# 5524             0             0             0             0             0
# 2174             0             0             0             0             0
# 4141             0             0             0             0             0
# 6182             0             0             0             0             0
# 5324             0             0             0             0             0
#
#       Complain  Z_CostContact  Z_Revenue  Response
# ID
# 5524         0              3         11         1
# 2174         0              3         11         0
# 4141         0              3         11         0
# 6182         0              3         11         0
# 5324         0              3         11         0
#
# [5 rows x 28 columns]

# %%
# 모두 대문자로 변환
cus.applymap(str).applymap(uppercase)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20684\4221682678.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   cus.applymap(str).applymap(uppercase)
#       Year_Birth   Education Marital_Status   Income Kidhome Teenhome  \
# ID
# 5524        1957  GRADUATION         SINGLE  58138.0    자녀없음        0
# 2174        1954  GRADUATION         SINGLE  46344.0      외동        1
# 4141        1965  GRADUATION       TOGETHER  71613.0    자녀없음        0
# 6182        1984  GRADUATION       TOGETHER  26646.0      외동        0
# 5324        1981         PHD        MARRIED  58293.0      외동        0
# ...          ...         ...            ...      ...     ...      ...
# 10870       1967  GRADUATION        MARRIED  61223.0    자녀없음        1
# 4001        1946         PHD       TOGETHER  64014.0     다자녀        1
# 7270        1981  GRADUATION       DIVORCED  56981.0    자녀없음        0
# 8235        1956      MASTER       TOGETHER  69245.0    자녀없음        1
# 9405        1954         PHD        MARRIED  52869.0      외동        1
#
#       Dt_Customer Recency MntWines MntFruits  ... NumWebVisitsMonth  \
# ID                                            ...
# 5524   04-09-2012      58      635        88  ...                 7
# 2174   08-03-2014      38       11         1  ...                 5
# 4141   21-08-2013      26      426        49  ...                 4
# 6182   10-02-2014      26       11         4  ...                 6
# 5324   19-01-2014      94      173        43  ...                 5
# ...           ...     ...      ...       ...  ...               ...
# 10870  13-06-2013      46      709        43  ...                 5
# 4001   10-06-2014      56      406         0  ...                 7
# 7270   25-01-2014      91      908        48  ...                 6
# 8235   24-01-2014       8      428        30  ...                 3
# 9405   15-10-2012      40       84         3  ...                 7
#
#       AcceptedCmp3 AcceptedCmp4 AcceptedCmp5 AcceptedCmp1 AcceptedCmp2  \
# ID
# 5524             0            0            0            0            0
# 2174             0            0            0            0            0
# 4141             0            0            0            0            0
# 6182             0            0            0            0            0
# 5324             0            0            0            0            0
# ...            ...          ...          ...          ...          ...
# 10870            0            0            0            0            0
# 4001             0            0            0            1            0
# 7270             0            1            0            0            0
# 8235             0            0            0            0            0
# 9405             0            0            0            0            0
#
#       Complain Z_CostContact Z_Revenue Response
# ID
# 5524         0             3        11        1
# 2174         0             3        11        0
# 4141         0             3        11        0
# 6182         0             3        11        0
# 5324         0             3        11        0
# ...        ...           ...       ...      ...
# 10870        0             3        11        0
# 4001         0             3        11        0
# 7270         0             3        11        0
# 8235         0             3        11        0
# 9405         0             3        11        1
#
# [2240 rows x 28 columns]
