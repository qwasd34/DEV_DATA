# %% [markdown]
# ## 데이터셋
# - 고객 성격 분석 : https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis

# %%
import pandas as pd

# %%
cus = pd.read_csv('marketing_campaign.csv', sep='\t', index_col='ID')
cus
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %% [markdown]
# ## copy() - 데이터프레임/시리즈의 복제
# 원본과 분리해서 작업하고 싶을 때 사용

# %%
# 복제 방법
cus_copy=cus.copy()

# %%
cus
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %%
cus_copy
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %%
# 주소 비교 다름!! 다른 주소에 존재
id(cus), id(cus_copy)
# Out:
# (2265949249488, 2265949355728)

# %%
# 값 비교 1 각각의 값이 T/F이나옴
cus==cus_copy
# Out:
#        Year_Birth  Education  Marital_Status  Income  Kidhome  Teenhome  \
# ID
# 5524         True       True            True    True     True      True
# 2174         True       True            True    True     True      True
# 4141         True       True            True    True     True      True
# 6182         True       True            True    True     True      True
# 5324         True       True            True    True     True      True
# ...           ...        ...             ...     ...      ...       ...
# 10870        True       True            True    True     True      True
# 4001         True       True            True    True     True      True
# 7270         True       True            True    True     True      True
# 8235         True       True            True    True     True      True
# 9405         True       True            True    True     True      True
#
#        Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %%
# 값 비교 2
cus.equals(cus_copy)
# Out:
# True

# %%
# 주소값 비교
cus is cus_copy
# Out:
# False

# %% [markdown]
# ## .copy()를 잘 이해하고 사용하자. 그렇지 않으면

# %%
# 결혼 상태 Series
ms=cus['Marital_Status']
ms
# Out:
# ID
# 5524       Single
# 2174       Single
# 4141     Together
# 6182     Together
# 5324      Married
#            ...
# 10870     Married
# 4001     Together
# 7270     Divorced
# 8235     Together
# 9405      Married
# Name: Marital_Status, Length: 2240, dtype: object

# %%
# 값을 변경하면 에러가 발생한다.
#customer 의 값도 변경이 되버려 warning 메세지 ... ms는 cus의 참조해서 만든 시리즈라! 
ms[0:3]='ooo'
ms
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22556\2397999904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ms[0:3]='ooo'
# ID
# 5524          ooo
# 2174          ooo
# 4141          ooo
# 6182     Together
# 5324      Married
#            ...
# 10870     Married
# 4001     Together
# 7270     Divorced
# 8235     Together
# 9405      Married
# Name: Marital_Status, Length: 2240, dtype: object

# %% [markdown]
# ```
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marital_status[0:3] = 'OOO'
# ```

# %% [markdown]
# - 메시지는 데이터프레임의 일부를 슬라이싱하여 얻은 복사본에 값을 설정하려고 할 때 발생하는 경고
# - 데이터프레임의 슬라이스가 원본 데이터프레임의 뷰(View)가 아닌 복사본(Copy)인 경우에 발생하는 경고.

# %%
# 원본의 데이터가 변경되어있다.
cus.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation            ooo  58138.0        0         0
# 2174        1954  Graduation            ooo  46344.0        1         1
# 4141        1965  Graduation            ooo  71613.0        0         0
# 6182        1984  Graduation       Together  26646.0        1         0
# 5324        1981         PhD        Married  58293.0        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  04-09-2012       58       635         88  ...                  7
# 2174  08-03-2014       38        11          1  ...                  5
# 4141  21-08-2013       26       426         49  ...                  4
# 6182  10-02-2014       26        11          4  ...                  6
# 5324  19-01-2014       94       173         43  ...                  5
#
# ...

# %% [markdown]
# ## .copy() - 원래 의도는 별도의 데이터프레임을 만들고 작업하려고 했던 거라면

# %%
# 초기화
cus = pd.read_csv('marketing_campaign.csv', sep='\t', index_col='ID')

# %%
# .copy() 안전하게 작업
ms=cus['Marital_Status'].copy()

# %%
ms[0:3]='ooo'
ms
# Out:
# ID
# 5524          ooo
# 2174          ooo
# 4141          ooo
# 6182     Together
# 5324      Married
#            ...
# 10870     Married
# 4001     Together
# 7270     Divorced
# 8235     Together
# 9405      Married
# Name: Marital_Status, Length: 2240, dtype: object

# %%
cus
#원본은 안변함
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...
