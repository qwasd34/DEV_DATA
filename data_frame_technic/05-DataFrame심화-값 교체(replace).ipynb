# %% [markdown]
# ## 데이터셋
# - 고객 성격 분석 : https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis

# %%
import pandas as pd

# %%
cus = pd.read_csv('marketing_campaign.csv', sep='\t', index_col='ID')
cus
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %% [markdown]
# ## .replace()
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html

# %%
cus['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %% [markdown]
# | 결혼 상태   | 인원 수 | 뜻 |
# |-----------|--------| -- |
# | Married   | 864    | 기혼 |
# | Together  | 580    | 동거 |
# | Single    | 480    | 독신 |
# | Divorced  | 232    | 이혼 |
# | Widow     | 77     | 미망 |
# | Alone     | 3      | 혼자, 싱글|
# | Absurd    | 2      | 터무니없는 |
# | YOLO      | 2      | 욜로 인생 |
#
# 이 중 Alone, Absurd, YOLO는 해석에 애매한 부분이 있다.
# 해당 데이터의 토론에도 이슈가 있으며
# YOLO같은 경우는 일반적인 Single과는 다른 고객패턴이 있음을 표시하고 싶었던 것 일수도.
#
# 여기서는 이 3가지를 Single로 귀속시켜보자.

# %%
# 방법 1. 시리즈.replace(dict)
cus['Marital_Status'].replace({'Alone': 'Single','Absurd': 'Single','YOLO': 'Single'})
cus['Marital_Status'].replace({'Alone': 'Single','Absurd': 'Single','YOLO': 'Single'}).value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      487
# Divorced    232
# Widow        77
# Name: count, dtype: int64

# %%
# 방법 2. 시리즈.replace(to_replace:list, value)
cus['Marital_Status'].replace(['Alone', 'Absurd', 'YOLO'], 'Single')
cus['Marital_Status'].replace(['Alone', 'Absurd', 'YOLO'], 'Single').value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      487
# Divorced    232
# Widow        77
# Name: count, dtype: int64

# %% [markdown]
# 다양한 replace() 예제는 아래서 살펴보자.
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html
# - 정규표현식도 있다.

# %%
# 방법 3. 데이터프레임.replace() 전범위에대해 replace 를 하게됨
cus.replace({'Alone': 'Single','Absurd': 'Single','YOLO': 'Single'})
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %%
cus.replace({'Alone': 'Single','Absurd': 'Single','YOLO': 'Single'})['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      487
# Divorced    232
# Widow        77
# Name: count, dtype: int64

# %% [markdown]
# Series.replace와 Dataframe.replace의 차이는 탐색&변경의 범위

# %%
# Inplcae=True로 원본에 반영하기
cus.replace({'Alone': 'Single','Absurd': 'Single','YOLO': 'Single'}, inplace=True)

# %% [markdown]
# ## 없는 값을 바꾸려고 하면?

# %%
cus.replace('tmvpse', 00)
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %% [markdown]
# 아무 에러도 발생하지 않는다.
